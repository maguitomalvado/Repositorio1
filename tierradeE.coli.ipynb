# %%
## la tarea esta debajo de esto

# %%
rt = 6371
rtm = rt * 1000
vt = mt.pi * (rtm) * 4/3
print(vt)
# Out:
# 26686782.394694094

# %%
rb = 0.5
re_c = rb * (10**-6)
vole_c = mt.pi * (re_c**3) * 4/3
print (vole_c)
# Out:
# 5.235987755982988e-19

# %%
ne_c = vt/vole_c
print (ne_c)
# Out:
# 5.0968e+25

# %%
n = ((rt * (10 ** 3)) ** 3)/((rb * (10 ** -6)) ** 3)
print (n)
# Out:
# 2.0687728224880002e+39

# %%
mt.log
# Out:
# <function math.log>

# %%
mediashoras = mt.log2 (n)
print (mediashoras)
# Out:
# 130.6039709282774

# %%
hora = mediashoras/2

# %%
print (hora)
# Out:
# 65.3019854641387

# %%
dia = hora/24
print (dia)
# Out:
# 2.720916061005779

# %%
### Tarea 10 de sept
import math as mt

# %%
## ejercicio 1 
rt = 6371
rb = 0.5
n = ((rt * (10 ** 3)) ** 3)/((rb * (10 ** -6)) ** 3)
mediashoras = mt.log2 (n)
print (mediashoras)
hora = mediashoras/2
print (hora)
dia = hora/24
print (dia)
# Out:
# 130.6039709282774
# 65.3019854641387
# 2.720916061005779

# %%
## ejercicio 2 
rt = 6371
rb = 0.5
n = (4*(rt * (10 ** 3)) ** 2)/((rb * (10 ** -6)) ** 2)
mediashoras = mt.log2 (n)
print (mediashoras)
hora = mediashoras/2
print (hora)
dia = hora/24
print (dia)
# Out:
# 89.06931395218493
# 44.534656976092464
# 1.855610707337186

# %%
## ejercicio 3 cuartos de hora
rt = 6371
rb = 0.5
n = ((rt * (10 ** 3)) ** 3)/((rb * (10 ** -6)) ** 3)
t = mt.log2 (n)
print (t)
hora = t/4
print (hora)
dia = hora/24
print (dia)
# Out:
# 130.6039709282774
# 32.65099273206935
# 1.3604580305028895

# %%
## ejercicio 3 cada hora
rt = 6371
rb = 0.5
n = ((rt * (10 ** 3)) ** 3)/((rb * (10 ** -6)) ** 3)
t = mt.log2 (n)
print (t)
hora = t
dia = hora/24
print (dia)
# Out:
# 130.6039709282774
# 5.441832122011558
